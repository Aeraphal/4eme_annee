# %% [markdown]
# TP de ligne de partage des eaux

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# Pré-traitement

# %% [markdown]
# Etape 1 - Lecture de l'image

# %%
Im_sm = cv2.imread('smarties.png',0)
plt.figure(figsize=(10,10))
plt.imshow(Im_sm, 'gray')
